# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout

# Load data from CSV
data = pd.read_csv("/content/sample_data/high_speed_data.csv")

# Drop rows with missing values
data.dropna(inplace=True)

# Prepare sequences
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data.iloc[i:(i + seq_length)][['ROLL_BAD', 'PITCH_BAD']].values
        y = data.iloc[i + seq_length][['ROLL_FILTERED', 'PITCH_FILTERED']].values
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

SEQ_LENGTH = 30  # Define the sequence length
X, y = create_sequences(data, SEQ_LENGTH)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# Initialize and build the GRU model
model = Sequential()
model.add(GRU(units=100, return_sequences=True, input_shape=(SEQ_LENGTH, X_train.shape[2])))
model.add(Dropout(0.2))  # Add dropout for regularization
model.add(GRU(units=50, return_sequences=False))
model.add(Dense(units=50, activation='relu'))  # Add a dense layer
model.add(Dense(units=2))  # The output layer should match the number of outputs

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)  # Adjust learning rate if needed
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Calculate R-squared
r_squared = r2_score(y_test, y_pred)
print("R-squared:", r_squared)
print("The accuracy of our model is {}%".format(round(r_squared, 2) * 100))
# Out:
# Epoch 1/100
# 203/203 [==============================] - 14s 44ms/step - loss: 3713.6353 - val_loss: 2580.4287
# Epoch 2/100
# 203/203 [==============================] - 9s 46ms/step - loss: 1957.1796 - val_loss: 1823.0127
# Epoch 3/100
# 203/203 [==============================] - 9s 43ms/step - loss: 1515.1748 - val_loss: 1625.4033
# Epoch 4/100
# 203/203 [==============================] - 8s 42ms/step - loss: 1277.1373 - val_loss: 1367.5427
# Epoch 5/100
# 203/203 [==============================] - 9s 46ms/step - loss: 1113.6899 - val_loss: 1209.4073
# Epoch 6/100
# 203/203 [==============================] - 9s 42ms/step - loss: 959.8655 - val_loss: 1082.6040
# Epoch 7/100
# 203/203 [==============================] - 9s 43ms/step - loss: 841.4578 - val_loss: 876.0910
# Epoch 8/100
# 203/203 [==============================] - 10s 47ms/step - loss: 759.4628 - val_loss: 833.1942
# Epoch 9/100
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout

# Load data from CSV
data = pd.read_csv("/content/sample_data/fast_moving_data.csv")

# Drop rows with missing values
data.dropna(inplace=True)

# Prepare sequences
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data.iloc[i:(i + seq_length)][['ROLL_BAD', 'PITCH_BAD']].values
        y = data.iloc[i + seq_length][['ROLL_FILTERED', 'PITCH_FILTERED']].values
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

SEQ_LENGTH = 30  # Define the sequence length
X, y = create_sequences(data, SEQ_LENGTH)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# Initialize and build the GRU model
model = Sequential()
model.add(GRU(units=100, return_sequences=True, input_shape=(SEQ_LENGTH, X_train.shape[2])))
model.add(Dropout(0.2))  # Add dropout for regularization
model.add(GRU(units=50, return_sequences=False))
model.add(Dense(units=50, activation='relu'))  # Add a dense layer
model.add(Dense(units=2))  # The output layer should match the number of outputs

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)  # Adjust learning rate if needed
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Calculate R-squared
r_squared = r2_score(y_test, y_pred)
print("R-squared:", r_squared)
print("The accuracy of our model is {}%".format(round(r_squared, 2) * 100))
# Out:
# Epoch 1/10
# 153/153 [==============================] - 12s 53ms/step - loss: 1608.2964 - val_loss: 1084.0668
# Epoch 2/10
# 153/153 [==============================] - 7s 47ms/step - loss: 942.3251 - val_loss: 767.1766
# Epoch 3/10
# 153/153 [==============================] - 6s 42ms/step - loss: 713.3865 - val_loss: 622.9619
# Epoch 4/10
# 153/153 [==============================] - 7s 47ms/step - loss: 555.2114 - val_loss: 489.5079
# Epoch 5/10
# 153/153 [==============================] - 7s 43ms/step - loss: 425.9261 - val_loss: 392.8920
# Epoch 6/10
# 153/153 [==============================] - 7s 46ms/step - loss: 328.9409 - val_loss: 313.9337
# Epoch 7/10
# 153/153 [==============================] - 7s 44ms/step - loss: 268.8099 - val_loss: 285.0276
# Epoch 8/10
# 153/153 [==============================] - 7s 44ms/step - loss: 228.1742 - val_loss: 239.2623
# Epoch 9/10
# 153/153 [==============================] - 7s 44ms/step - loss: 203.3247 - val_loss: 203.1892
# Epoch 10/10
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout

# Load data from CSV
data = pd.read_csv("/content/sample_data/Book1.csv")

# Drop rows with missing values
data.dropna(inplace=True)

# Prepare sequences
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data.iloc[i:(i + seq_length)][['ROLL_BAD', 'PITCH_BAD']].values
        y = data.iloc[i + seq_length][['ROLL_FILTERED', 'PITCH_FILTERED']].values
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

SEQ_LENGTH = 30  # Define the sequence length
X, y = create_sequences(data, SEQ_LENGTH)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# Initialize and build the GRU model
model = Sequential()
model.add(GRU(units=100, return_sequences=True, input_shape=(SEQ_LENGTH, X_train.shape[2])))
model.add(Dropout(0.2))  # Add dropout for regularization
model.add(GRU(units=50, return_sequences=False))
model.add(Dense(units=50, activation='relu'))  # Add a dense layer
model.add(Dense(units=2))  # The output layer should match the number of outputs

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)  # Adjust learning rate if needed
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Calculate R-squared
r_squared = r2_score(y_test, y_pred)
print("R-squared:", r_squared)
print("The accuracy of our model is {}%".format(round(r_squared, 2) * 100))
# Out:
# Epoch 1/10
# 200/200 [==============================] - 15s 54ms/step - loss: 416.1730 - val_loss: 191.7509
# Epoch 2/10
# 200/200 [==============================] - 10s 49ms/step - loss: 157.6918 - val_loss: 139.0845
# Epoch 3/10
# 200/200 [==============================] - 8s 41ms/step - loss: 122.4632 - val_loss: 111.5756
# Epoch 4/10
# 200/200 [==============================] - 10s 49ms/step - loss: 102.5148 - val_loss: 98.3188
# Epoch 5/10
# 200/200 [==============================] - 10s 49ms/step - loss: 88.4145 - val_loss: 84.9005
# Epoch 6/10
# 200/200 [==============================] - 8s 41ms/step - loss: 77.5430 - val_loss: 74.7931
# Epoch 7/10
# 200/200 [==============================] - 10s 50ms/step - loss: 66.3610 - val_loss: 63.4962
# Epoch 8/10
# 200/200 [==============================] - 10s 51ms/step - loss: 59.0169 - val_loss: 57.2357
# Epoch 9/10
# 200/200 [==============================] - 8s 42ms/step - loss: 51.1248 - val_loss: 58.2587
# Epoch 10/10
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout

# Load data from CSV
data = pd.read_csv("/content/sample_data/vibration_data.csv")

# Drop rows with missing values
data.dropna(inplace=True)

# Prepare sequences
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data.iloc[i:(i + seq_length)][['ROLL_BAD', 'PITCH_BAD']].values
        y = data.iloc[i + seq_length][['ROLL_FILTERED', 'PITCH_FILTERED']].values
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

SEQ_LENGTH = 30  # Define the sequence length
X, y = create_sequences(data, SEQ_LENGTH)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# Initialize and build the GRU model
model = Sequential()
model.add(GRU(units=100, return_sequences=True, input_shape=(SEQ_LENGTH, X_train.shape[2])))
model.add(Dropout(0.2))  # Add dropout for regularization
model.add(GRU(units=50, return_sequences=False))
model.add(Dense(units=50, activation='relu'))  # Add a dense layer
model.add(Dense(units=2))  # The output layer should match the number of outputs

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)  # Adjust learning rate if needed
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Calculate R-squared
r_squared = r2_score(y_test, y_pred)
print("R-squared:", r_squared)
print("The accuracy of our model is {}%".format(round(r_squared, 2) * 100))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 8s 60ms/step - loss: 210.3649 - val_loss: 118.1997
# Epoch 2/10
# 60/60 [==============================] - 2s 39ms/step - loss: 80.4178 - val_loss: 52.6750
# Epoch 3/10
# 60/60 [==============================] - 2s 39ms/step - loss: 42.3506 - val_loss: 32.8752
# Epoch 4/10
# 60/60 [==============================] - 2s 39ms/step - loss: 29.0740 - val_loss: 23.9003
# Epoch 5/10
# 60/60 [==============================] - 3s 58ms/step - loss: 23.3401 - val_loss: 20.0828
# Epoch 6/10
# 60/60 [==============================] - 3s 45ms/step - loss: 20.7814 - val_loss: 18.9688
# Epoch 7/10
# 60/60 [==============================] - 2s 39ms/step - loss: 18.3038 - val_loss: 16.4282
# Epoch 8/10
# 60/60 [==============================] - 2s 39ms/step - loss: 16.6379 - val_loss: 16.1269
# Epoch 9/10
# 60/60 [==============================] - 2s 38ms/step - loss: 15.6564 - val_loss: 14.4994
# Epoch 10/10
# ...
